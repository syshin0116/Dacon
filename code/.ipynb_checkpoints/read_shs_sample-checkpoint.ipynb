# %%
import geopandas as gpd
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = 'NanumGothic'
plt.rcParams["font.size"] = 13
plt.rcParams["figure.figsize"] = (10,10)

# %%
# ArcGIS or GIS에서는 SHP파일만 가져와서 읽지만, python은 .dbf, .shx파일도 함께 있어야힌다. 
seoul_file = "D:/201812기초구역DB_전체분/서울특별시/TL_KODIS_BAS_11.shp"
seoul = gpd.read_file(seoul_file)
seoul
seoul= seoul[seoul.SIG_KOR_NM=="종로구"]
seoul
# Out:
#       BAS_MGT_SN CTP_KOR_NM SIG_CD SIG_KOR_NM BAS_ID    BAS_AR   NTFC_DE  \
# 1082  1111000027      서울특별시  11110        종로구  03165  0.085469  20161027
# 1083  1111000028      서울특별시  11110        종로구  03166  0.042211  20161027
# 1243  1111000194      서울특별시  11110        종로구  03026  0.065817  20121221
# 4215  1111000039      서울특별시  11110        종로구  03046  0.085627  20121221
# 4216  1111000040      서울특별시  11110        종로구  03169  0.050266  20121221
# ...          ...        ...    ...        ...    ...       ...       ...
# 4507  1111000037      서울특별시  11110        종로구  03015  0.153172  20121221
# 4508  1111000038      서울특별시  11110        종로구  03018  0.046852  20121221
# 4509  1111000111      서울특별시  11110        종로구  03002  0.521175  20121221
# 4510  1111000112      서울특별시  11110        종로구  03058  0.048406  20121221
# 4511  1111000183      서울특별시  11110        종로구  03048  0.569912  20121221
#
#        MVMN_DE               MVMN_RESN        OPERT_DE  \
# 1082  20161027          통합에 의한 기초구역 변경  20161027000000
# 1083  20161027  기초구역 경계 변경에 의한 기초구역 변경  20161027000000
# 1243  20161027  기초구역 경계 변경에 의한 기초구역 변경  20161027000000
# 4215      None                    None            None
# 4216      None                    None            None
# ...        ...                     ...             ...
# 4507      None                    None            None
# 4508      None                    None            None
# 4509      None                    None            None
# 4510      None                    None            None
# 4511      None                    None            None
#
#                                                geometry
# 1082  POLYGON ((952562.7489632175 1952608.521237949,...
# 1083  POLYGON ((952842.2750962807 1952424.564815845,...
# 1243  POLYGON ((952706.6982702278 1952771.034203802,...
# 4215  POLYGON ((953195.3757915294 1954737.211081077,...
# 4216  POLYGON ((953437.1957128232 1953082.121450884,...
# ...                                                 ...
# 4507  POLYGON ((952092.2171971878 1956111.384592436,...
# 4508  POLYGON ((952580.1701817187 1955803.287147562,...
# 4509  POLYGON ((953333.3776387684 1957708.031087823,...
# 4510  POLYGON ((954902.4466217085 1953446.630926861,...
# 4511  POLYGON ((953343.3916821418 1955051.034242386,...
#
# [198 rows x 11 columns]

# %%
ax = seoul.convex_hull.plot(color='purple', edgecolor="w")
ax.set_title("종로구 기초구역도")
ax.set_axis_off()
plt.show()
